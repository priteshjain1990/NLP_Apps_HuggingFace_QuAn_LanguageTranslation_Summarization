# %%
#Please execute this notebook on the course python environment
#This installs all the pre-requisities for the course

# !pip install tensorflow===2.10.0
# !pip install torch
# !pip install keras===2.10.0
# !pip install transformers
# !pip install datasets
# !pip install sentencepiece
# !pip install evaluate
# !pip install nltk
# !pip install rouge_score
# Out:
# Collecting tensorflow===2.10.0
#   Downloading tensorflow-2.10.0-cp39-cp39-macosx_10_14_x86_64.whl (241.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.2/241.2 MB 11.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from tensorflow===2.10.0) (65.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from tensorflow===2.10.0) (4.4.0)
# Collecting flatbuffers>=2.0
#   Downloading flatbuffers-22.12.6-py2.py3-none-any.whl (26 kB)
# Collecting absl-py>=1.0.0
#   Using cached absl_py-1.3.0-py3-none-any.whl (124 kB)
# Collecting h5py>=2.9.0
#   Using cached h5py-3.7.0-cp39-cp39-macosx_10_9_x86_64.whl (3.2 MB)
# Collecting libclang>=13.0.0
#   Using cached libclang-14.0.6-py2.py3-none-macosx_10_9_x86_64.whl (13.2 MB)
# Collecting tensorboard<2.11,>=2.10
#   Downloading tensorboard-2.10.1-py3-none-any.whl (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 52.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: packaging in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from tensorflow===2.10.0) (21.3)
# Collecting keras-preprocessing>=1.1.1
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 3.0 MB/s eta 0:00:00
# Collecting protobuf<3.20,>=3.9.2
#   Using cached protobuf-3.19.6-cp39-cp39-macosx_10_9_x86_64.whl (980 kB)
# Collecting termcolor>=1.1.0
#   Using cached termcolor-2.1.1-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: six>=1.12.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from tensorflow===2.10.0) (1.16.0)
# Collecting grpcio<2.0,>=1.24.3
#   Using cached grpcio-1.51.1-cp39-cp39-macosx_10_10_x86_64.whl (4.6 MB)
# Collecting wrapt>=1.11.0
#   Using cached wrapt-1.14.1-cp39-cp39-macosx_10_9_x86_64.whl (35 kB)
# Collecting tensorflow-estimator<2.11,>=2.10.0
#   Downloading tensorflow_estimator-2.10.0-py2.py3-none-any.whl (438 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.7/438.7 kB 18.1 MB/s eta 0:00:00
# Collecting keras<2.11,>=2.10.0
#   Downloading keras-2.10.0-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 40.0 MB/s eta 0:00:0000:01
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting numpy>=1.20
#   Using cached numpy-1.23.5-cp39-cp39-macosx_10_9_x86_64.whl (18.1 MB)
# Collecting gast<=0.4.0,>=0.2.1
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Using cached tensorflow_io_gcs_filesystem-0.28.0-cp39-cp39-macosx_10_14_x86_64.whl (1.6 MB)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow===2.10.0) (0.37.1)
# Collecting werkzeug>=1.0.1
#   Using cached Werkzeug-2.2.2-py3-none-any.whl (232 kB)
# Collecting requests<3,>=2.21.0
#   Using cached requests-2.28.1-py3-none-any.whl (62 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached tensorboard_data_server-0.6.1-py3-none-macosx_10_9_x86_64.whl (3.5 MB)
# Collecting google-auth<3,>=1.6.3
#   Using cached google_auth-2.15.0-py2.py3-none-any.whl (177 kB)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.4.1-py3-none-any.whl (93 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from packaging->tensorflow===2.10.0) (3.0.9)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting importlib-metadata>=4.4
#   Using cached importlib_metadata-5.1.0-py3-none-any.whl (21 kB)
# Collecting charset-normalizer<3,>=2
#   Using cached charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Using cached urllib3-1.26.13-py2.py3-none-any.whl (140 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (2.1.1)
# Collecting zipp>=0.5
#   Using cached zipp-3.11.0-py3-none-any.whl (6.6 kB)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Installing collected packages: tensorboard-plugin-wit, pyasn1, libclang, keras, flatbuffers, zipp, wrapt, werkzeug, urllib3, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, rsa, pyasn1-modules, protobuf, oauthlib, numpy, grpcio, google-pasta, gast, charset-normalizer, cachetools, astunparse, absl-py, requests, opt-einsum, keras-preprocessing, importlib-metadata, h5py, google-auth, requests-oauthlib, markdown, google-auth-oauthlib, tensorboard, tensorflow
# Successfully installed absl-py-1.3.0 astunparse-1.6.3 cachetools-5.2.0 charset-normalizer-2.1.1 flatbuffers-22.12.6 gast-0.4.0 google-auth-2.15.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.51.1 h5py-3.7.0 importlib-metadata-5.1.0 keras-2.10.0 keras-preprocessing-1.1.2 libclang-14.0.6 markdown-3.4.1 numpy-1.23.5 oauthlib-3.2.2 opt-einsum-3.3.0 protobuf-3.19.6 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-2.28.1 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.10.1 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.10.0 tensorflow-estimator-2.10.0 tensorflow-io-gcs-filesystem-0.28.0 termcolor-2.1.1 urllib3-1.26.13 werkzeug-2.2.2 wrapt-1.14.1 zipp-3.11.0
# Collecting torch
#   Using cached torch-1.13.0-cp39-none-macosx_10_9_x86_64.whl (137.9 MB)
# Requirement already satisfied: typing-extensions in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from torch) (4.4.0)
# Installing collected packages: torch
# Successfully installed torch-1.13.0
# Requirement already satisfied: keras===2.10.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (2.10.0)
# Collecting transformers
#   Using cached transformers-4.25.1-py3-none-any.whl (5.8 MB)
# Collecting pyyaml>=5.1
#   Using cached PyYAML-6.0-cp39-cp39-macosx_10_9_x86_64.whl (197 kB)
# Requirement already satisfied: requests in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from transformers) (2.28.1)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from transformers) (21.3)
# Collecting huggingface-hub<1.0,>=0.10.0
#   Using cached huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
# Collecting filelock
#   Using cached filelock-3.8.2-py3-none-any.whl (10 kB)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Using cached tokenizers-0.13.2-cp39-cp39-macosx_10_11_x86_64.whl (3.8 MB)
# Collecting tqdm>=4.27
#   Using cached tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
# Collecting regex!=2019.12.17
#   Using cached regex-2022.10.31-cp39-cp39-macosx_10_9_x86_64.whl (293 kB)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from transformers) (1.23.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from requests->transformers) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from requests->transformers) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from requests->transformers) (2022.9.24)
# Installing collected packages: tokenizers, tqdm, regex, pyyaml, filelock, huggingface-hub, transformers
# Successfully installed filelock-3.8.2 huggingface-hub-0.11.1 pyyaml-6.0 regex-2022.10.31 tokenizers-0.13.2 tqdm-4.64.1 transformers-4.25.1
# Collecting datasets
#   Using cached datasets-2.7.1-py3-none-any.whl (451 kB)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.2.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from datasets) (0.11.1)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from datasets) (1.23.5)
# Collecting multiprocess
#   Using cached multiprocess-0.70.14-py39-none-any.whl (132 kB)
# Collecting aiohttp
#   Using cached aiohttp-3.8.3-cp39-cp39-macosx_10_9_x86_64.whl (360 kB)
# Collecting pandas
#   Using cached pandas-1.5.2-cp39-cp39-macosx_10_9_x86_64.whl (12.1 MB)
# Collecting dill<0.3.7
#   Using cached dill-0.3.6-py3-none-any.whl (110 kB)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from datasets) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from datasets) (6.0)
# Collecting fsspec[http]>=2021.11.1
#   Using cached fsspec-2022.11.0-py3-none-any.whl (139 kB)
# Collecting xxhash
#   Using cached xxhash-3.1.0-cp39-cp39-macosx_10_9_x86_64.whl (34 kB)
# Requirement already satisfied: tqdm>=4.62.1 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from datasets) (4.64.1)
# Collecting pyarrow>=6.0.0
#   Using cached pyarrow-10.0.1-cp39-cp39-macosx_10_14_x86_64.whl (25.1 MB)
# Collecting responses<0.19
#   Using cached responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: requests>=2.19.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from datasets) (2.28.1)
# Collecting multidict<7.0,>=4.5
#   Using cached multidict-6.0.3-cp39-cp39-macosx_10_9_x86_64.whl (29 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Using cached async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting frozenlist>=1.1.1
#   Using cached frozenlist-1.3.3-cp39-cp39-macosx_10_9_x86_64.whl (36 kB)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from aiohttp->datasets) (2.1.1)
# Collecting aiosignal>=1.1.2
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting yarl<2.0,>=1.0
#   Using cached yarl-1.8.2-cp39-cp39-macosx_10_9_x86_64.whl (61 kB)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (3.8.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from packaging->datasets) (3.0.9)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from requests>=2.19.0->datasets) (2022.9.24)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from pandas->datasets) (2.8.2)
# Collecting pytz>=2020.1
#   Using cached pytz-2022.6-py2.py3-none-any.whl (498 kB)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: pytz, xxhash, pyarrow, multidict, fsspec, frozenlist, dill, async-timeout, yarl, responses, pandas, multiprocess, aiosignal, aiohttp, datasets
# Successfully installed aiohttp-3.8.3 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.7.1 dill-0.3.6 frozenlist-1.3.3 fsspec-2022.11.0 multidict-6.0.3 multiprocess-0.70.14 pandas-1.5.2 pyarrow-10.0.1 pytz-2022.6 responses-0.18.0 xxhash-3.1.0 yarl-1.8.2
# Collecting sentencepiece
#   Using cached sentencepiece-0.1.97-cp39-cp39-macosx_10_9_x86_64.whl (1.2 MB)
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.97
# Collecting evaluate
#   Using cached evaluate-0.3.0-py3-none-any.whl (72 kB)
# Requirement already satisfied: responses<0.19 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from evaluate) (0.18.0)
# Requirement already satisfied: requests>=2.19.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from evaluate) (2.28.1)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from evaluate) (1.5.2)
# Requirement already satisfied: datasets>=2.0.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from evaluate) (2.7.1)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from evaluate) (21.3)
# Requirement already satisfied: xxhash in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from evaluate) (3.1.0)
# Requirement already satisfied: dill in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from evaluate) (0.3.6)
# Requirement already satisfied: multiprocess in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from evaluate) (0.70.14)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from evaluate) (0.11.1)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from evaluate) (2022.11.0)
# Requirement already satisfied: tqdm>=4.62.1 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from evaluate) (4.64.1)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from evaluate) (1.23.5)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from datasets>=2.0.0->evaluate) (6.0)
# Requirement already satisfied: aiohttp in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from datasets>=2.0.0->evaluate) (3.8.3)
# Requirement already satisfied: pyarrow>=6.0.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from datasets>=2.0.0->evaluate) (10.0.1)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from huggingface-hub>=0.7.0->evaluate) (3.8.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from huggingface-hub>=0.7.0->evaluate) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from packaging->evaluate) (3.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from requests>=2.19.0->evaluate) (1.26.13)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from requests>=2.19.0->evaluate) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from requests>=2.19.0->evaluate) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from requests>=2.19.0->evaluate) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from pandas->evaluate) (2022.6)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.8.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (22.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->evaluate) (1.16.0)
# Installing collected packages: evaluate
# Successfully installed evaluate-0.3.0
# Collecting nltk
#   Using cached nltk-3.7-py3-none-any.whl (1.5 MB)
# Collecting joblib
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from nltk) (4.64.1)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from nltk) (2022.10.31)
# Collecting click
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Installing collected packages: joblib, click, nltk
# Successfully installed click-8.1.3 joblib-1.2.0 nltk-3.7
# Collecting rouge_score
#   Using cached rouge_score-0.1.2-py3-none-any.whl
# Requirement already satisfied: numpy in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from rouge_score) (1.23.5)
# Requirement already satisfied: nltk in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from rouge_score) (3.7)
# Requirement already satisfied: six>=1.14.0 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: absl-py in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from rouge_score) (1.3.0)
# Requirement already satisfied: click in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from nltk->rouge_score) (8.1.3)
# Requirement already satisfied: joblib in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from nltk->rouge_score) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from nltk->rouge_score) (2022.10.31)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/transformers-2/lib/python3.9/site-packages (from nltk->rouge_score) (4.64.1)
# Installing collected packages: rouge_score
# Successfully installed rouge_score-0.1.2
